# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("shadow1206/kylbergtexturedata")

print("Path to dataset files:", path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 4
#       1 import kagglehub
#       3 # Download latest version
# ----> 4 path = kagglehub.dataset_download("shadow1206/kylbergtexturedata")
#       6 print("Path to dataset files:", path)
#
# AttributeError: module 'kagglehub' has no attribute 'dataset_download'
